# %%
# !nvidia-smi
# Out:
# Fri Jan 24 18:38:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
mount = '/content/gdrive'

from google.colab import drive
drive.mount(mount)

RESULT_PATH = '{}/My Drive/result/'.format(mount)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# model architecture
CLASSES = 10
FIRST_CH = 8
FEATURE_DIMS = 32
N_KERNELS = 4
CYCLE = 4

# hyper params
EPOCHS = 50
BATCH_SIZE = 300
LEARNING_RATE = 1e-2

# extras
LOG_INTERVAL = 200
GPU = 0
ALPHA = 0.03
START = 1
LOAD_MODEL = True

minimum_loss = 100.

# %%
import copy

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torchvision.datasets as dset
import torchvision.transforms as transforms

# %%
def zeropad(x, ch):
    return F.pad(x, (0, 0, 0, 0, 0, ch-x.size(1), 0, 0))

# %%
class Dense(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(Dense, self).__init__()
        self.main = nn.Sequential(
            nn.LeakyReLU(0.2),
            nn.Linear(in_ch, out_ch)
        )
        
    def forward(self, x):
        return self.main(x)

# %%
class SNDense(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(SNDense, self).__init__()
        self.main = nn.Sequential(
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Linear(in_ch, out_ch))
        )
        
    def forward(self, x):
        return self.main(x)

# %%
class BNConv(nn.Module):
    def __init__(self, in_ch, out_ch, kernel=1, stride=1, padding=0):
        super(BNConv, self).__init__()
        self.main = nn.Sequential(
            nn.LeakyReLU(0.2),
            nn.Conv2d(in_ch, out_ch, kernel, stride, padding),
            nn.BatchNorm2d(out_ch)
        )
        
    def forward(self, x, features=None):
        return self.main(x)

# %%
class SNConv(nn.Module):
    def __init__(self, in_ch, out_ch, kernel=1, stride=1, padding=0):
        super(SNConv, self).__init__()
        self.main = nn.Sequential(
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(in_ch, out_ch, kernel, stride, padding))
        )
        
    def forward(self, x, features=None):
        return self.main(x)

# %%
class CondConv(nn.Module):
    def __init__(self, feature_dims, n_kernels, kernel=3, stride=1, padding=1, device=None, k=1):
        super(CondConv, self).__init__()
        self.kernel = kernel
        self.stride = stride
        self.padding = padding
        self.kernels_size = (n_kernels, kernel, kernel)

        self.kernels = nn.Parameter(torch.empty(n_kernels*kernel*kernel, k, 1))
        nn.init.xavier_normal_(self.kernels)

        self.activate = nn.Tanh()
    
    def forward(self, x, features):
        b_size = x.size(0)

        h = F.leaky_relu(x, negative_slope=0.2)
        kernels = self.kernels.expand(-1, -1, h.size(1))
        i = torch.eye(h.size(1)).to(device).view(1, h.size(1), h.size(1)).expand(kernels.size(0), -1, -1)
        kernels = i*kernels
        kernels = kernels.view(*self.kernels_size, h.size(1), -1)
        kernels = kernels.transpose(1, 3).transpose(2, 4)
        kernels = kernels.expand(b_size, -1, -1, -1, -1, -1)

        f = self.activate(features)
        f = f.view(*kernels.size()[:3], 1, 1, 1)
        f = f.expand(-1, -1, -1, h.size(1), -1, -1)
        f = torch.sum(kernels*f, dim=1)

        f = f.reshape(b_size, h.size(1), -1)

        h = F.unfold(h, self.kernel, padding=self.padding, stride=self.stride)
        h = torch.bmm(f, h)
        h = h.view(*h.size()[:2], *x.size()[2:])
        return h

# %%
class Net(nn.Module):
    def __init__(self, classes, ch, feature_dims, n_kernels, cycle, device=None):
        super(Net, self).__init__()
        self.ch = [[ch, ch*2, ch*3],
                   [ch*4, ch*5, ch*6],
                   [ch*7, ch*8, ch*9],
                   [ch*10, ch*11, ch*12]]

        self.cc = CondConv(feature_dims, n_kernels, device=device)
        self.first_noise = nn.Parameter(torch.empty(1, feature_dims))
        nn.init.normal_(self.first_noise)
        
        self.extractor = nn.ModuleList(
            [nn.ModuleList(
                [SNConv(ch, ch*2),
                 SNConv(ch*2, ch*3),
                 SNConv(ch*3, ch*4)]
            ),
            nn.ModuleList(
                [SNConv(ch*4, ch*5),
                 SNConv(ch*5, ch*6),
                 SNConv(ch*6, ch*7)]
            ),
            nn.ModuleList(
                [SNConv(ch*7, ch*8),
                 SNConv(ch*8, ch*9),
                 SNConv(ch*9, ch*10)]
            ),
            nn.ModuleList(
                [SNConv(ch*10, ch*11),
                 SNConv(ch*11, ch*12),
                 SNConv(ch*12, ch*12)]
            )]
        )

        self.excites = nn.ModuleList(
            [nn.ModuleList(
                [nn.ModuleList(
                    [SNDense(feature_dims, n_kernels*__ch) for __ch in _ch]
                ) for _ch in self.ch]
            ) for _ in range(cycle)]
        )
        
        self.combines = nn.ModuleList(
            [copy.deepcopy(self.extractor) for _ in range(cycle)]
        )

        self.pool = nn.ModuleList(
            [nn.AdaptiveMaxPool2d((14, 14)),
             nn.AdaptiveMaxPool2d((8, 8)),
             nn.AdaptiveMaxPool2d((4, 4)),
             nn.Sequential(
                 nn.AvgPool2d(4),
                 nn.Flatten()
                 )]
            )

        self.feature = nn.Sequential(
            SNDense(self.ch[-1][-1], feature_dims*2),
            SNDense(feature_dims*2, feature_dims)
        )
        self.features = nn.ModuleList(
            [copy.deepcopy(self.feature) for _ in range(cycle)]
        )
        self.buttom = SNDense(feature_dims, classes)
    
    def forward(self, x, cycle):
        _x = x.expand(-1, self.ch[0][0], -1, -1)
        h = _x
        f = self.first_noise.expand(x.size(0), -1)

        for excite, combine, feature in zip(self.excites[:cycle], self.combines[:cycle], self.features[:cycle]):
            h = _x
            for _excite, _combine, pool in zip(excite, combine, self.pool):
                for __excite, __combine in zip(_excite, _combine):
                    _h = self.cc(h, __excite(f))
                    _h = __combine(_h)
                    h = zeropad(h, _h.size(1)) + _h
                h = pool(h)
            f = f + feature(h)

        out = self.buttom(f)
        return F.log_softmax(out, dim=1)

# %%
def train(model, device, train_loader, optimizer, epoch, cycle):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data, cycle)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % LOG_INTERVAL == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, device, test_loader, cycle):
    global minimum_loss
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data, cycle)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    if test_loss <= minimum_loss:
        torch.save(model.state_dict(), RESULT_PATH+'condconv_mnist.pkl')
        minimum_loss = test_loss

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
device = torch.device("cuda:{}".format(GPU))

# %%
def create_trainloader(alpha):
    kwargs = {'num_workers': 1, 'pin_memory': True}
    train_loader = torch.utils.data.DataLoader(
        dset.MNIST('./data', train=True, download=True,
                        transform=transforms.Compose([
                            transforms.RandomAffine(alpha),
                            transforms.RandomPerspective(alpha),
                            transforms.RandomRotation(alpha),
                            transforms.ToTensor(),
                            transforms.Normalize((0.1307,), (0.3081,))
                        ])),
        batch_size=BATCH_SIZE, shuffle=True, **kwargs)
    return train_loader

# %%
kwargs = {'num_workers': 1, 'pin_memory': True}
test_loader = torch.utils.data.DataLoader(
    dset.MNIST('./data', train=False, download=True,
               transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)

# %%
model = Net(CLASSES, FIRST_CH, FEATURE_DIMS, N_KERNELS, CYCLE, device).to(device)
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
if LOAD_MODEL:
    model.load_state_dict(torch.load(RESULT_PATH+'condconv_mnist.pkl'))
    model.eval()

# %%
def round(cycle, model, device, train_loader, test_loader, optimizer, epochs):
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, optimizer, epoch, cycle)
        test(model, device, test_loader, cycle)

# %%
for c in range(START, CYCLE + 1):
    alpha = ALPHA * c
    train_loader = create_trainloader(alpha)
    round(c, model, device, train_loader, test_loader, optimizer, EPOCHS)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.575047
#
# Test set: Average loss: 0.1697, Accuracy: 9462/10000 (95%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.198921
#
# Test set: Average loss: 0.0836, Accuracy: 9738/10000 (97%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.091139
#
# Test set: Average loss: 0.0504, Accuracy: 9837/10000 (98%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.027919
#
# Test set: Average loss: 0.0357, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.033114
#
# Test set: Average loss: 0.0315, Accuracy: 9895/10000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.013888
#
# Test set: Average loss: 0.0282, Accuracy: 9911/10000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.034205
#
# Test set: Average loss: 0.0289, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.042097
#
# Test set: Average loss: 0.0275, Accuracy: 9912/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.012578
#
# Test set: Average loss: 0.0205, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.007721
#
# Test set: Average loss: 0.0252, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.017771
#
# Test set: Average loss: 0.0244, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.005019
#
# Test set: Average loss: 0.0205, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.005911
#
# Test set: Average loss: 0.0300, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.004447
#
# Test set: Average loss: 0.0230, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.005336
#
# Test set: Average loss: 0.0237, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.000522
#
# Test set: Average loss: 0.0233, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.007100
#
# Test set: Average loss: 0.0209, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.001217
#
# Test set: Average loss: 0.0257, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.011328
#
# Test set: Average loss: 0.0242, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.008315
#
# Test set: Average loss: 0.0213, Accuracy: 9938/10000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.000700
#
# Test set: Average loss: 0.0294, Accuracy: 9922/10000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.007823
#
# Test set: Average loss: 0.0252, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.007632
#
# Test set: Average loss: 0.0598, Accuracy: 9835/10000 (98%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.057715
#
# Test set: Average loss: 0.0277, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.036081
#
# Test set: Average loss: 0.0302, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.008405
#
# Test set: Average loss: 0.0329, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.003677
#
# Test set: Average loss: 0.0361, Accuracy: 9922/10000 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.002315
#
# Test set: Average loss: 0.0206, Accuracy: 9946/10000 (99%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.000766
#
# Test set: Average loss: 0.0267, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.004188
#
# Test set: Average loss: 0.0324, Accuracy: 9906/10000 (99%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.005875
#
# Test set: Average loss: 0.0263, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.006560
#
# Test set: Average loss: 0.0231, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.029332
#
# Test set: Average loss: 0.0222, Accuracy: 9943/10000 (99%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.001156
#
# Test set: Average loss: 0.0273, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.002415
#
# Test set: Average loss: 0.0290, Accuracy: 9925/10000 (99%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.026943
#
# Test set: Average loss: 0.0283, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.001759
#
# Test set: Average loss: 0.0336, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.014043
#
# Test set: Average loss: 0.0258, Accuracy: 9940/10000 (99%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.002855
#
# Test set: Average loss: 0.0397, Accuracy: 9905/10000 (99%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.012733
#
# Test set: Average loss: 0.0278, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.003297
#
# Test set: Average loss: 0.0218, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.009912
#
# Test set: Average loss: 0.0228, Accuracy: 9939/10000 (99%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.002426
#
# Test set: Average loss: 0.0264, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.005456
#
# Test set: Average loss: 0.0279, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.000811
#
# Test set: Average loss: 0.0285, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.000404
#
# Test set: Average loss: 0.0239, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.000317
#
# Test set: Average loss: 0.0254, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.001143
#
# Test set: Average loss: 0.0248, Accuracy: 9942/10000 (99%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.001738
#
# Test set: Average loss: 0.0251, Accuracy: 9947/10000 (99%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.010772
#
# Test set: Average loss: 0.0279, Accuracy: 9941/10000 (99%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 0.001647
#
# Test set: Average loss: 0.0308, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.000865
#
# Test set: Average loss: 0.0340, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.002617
#
# Test set: Average loss: 0.0303, Accuracy: 9943/10000 (99%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.000260
#
# Test set: Average loss: 0.0220, Accuracy: 9940/10000 (99%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.000109
#
# Test set: Average loss: 0.0314, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.080530
#
# Test set: Average loss: 0.0359, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.000491
#
# Test set: Average loss: 0.0196, Accuracy: 9941/10000 (99%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.000254
#
# Test set: Average loss: 0.0275, Accuracy: 9943/10000 (99%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 0.000005
#
# Test set: Average loss: 0.0347, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.000006
#
# Test set: Average loss: 0.0290, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.003048
#
# Test set: Average loss: 0.0292, Accuracy: 9925/10000 (99%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.000758
#
# Test set: Average loss: 0.0265, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.001805
#
# Test set: Average loss: 0.0272, Accuracy: 9938/10000 (99%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.007382
#
# Test set: Average loss: 0.0438, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.010192
#
# Test set: Average loss: 0.0248, Accuracy: 9947/10000 (99%)
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.000012
#
# Test set: Average loss: 0.0338, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.003922
#
# Test set: Average loss: 0.0253, Accuracy: 9939/10000 (99%)
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.002796
#
# Test set: Average loss: 0.0279, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.001043
#
# Test set: Average loss: 0.0325, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.000696
#
# Test set: Average loss: 0.0332, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.000367
#
# Test set: Average loss: 0.0265, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.000114
#
# Test set: Average loss: 0.0280, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.000118
#
# Test set: Average loss: 0.0285, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.008483
#
# Test set: Average loss: 0.0281, Accuracy: 9938/10000 (99%)
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.000037
#
# Test set: Average loss: 0.0403, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.000167
#
# Test set: Average loss: 0.0287, Accuracy: 9941/10000 (99%)
#
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.000004
#
# Test set: Average loss: 0.0336, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.009723
#
# Test set: Average loss: 0.0331, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.010785
#
# Test set: Average loss: 0.0243, Accuracy: 9952/10000 (100%)
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.000067
#
# Test set: Average loss: 0.0231, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 0.000551
#
# Test set: Average loss: 0.0275, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.000026
#
# Test set: Average loss: 0.0228, Accuracy: 9950/10000 (100%)
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.000120
#
# Test set: Average loss: 0.0381, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.001338
#
# Test set: Average loss: 0.0226, Accuracy: 9954/10000 (100%)
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 0.000152
#
# Test set: Average loss: 0.0254, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.000236
#
# Test set: Average loss: 0.0259, Accuracy: 9957/10000 (100%)
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.000019
#
# Test set: Average loss: 0.0274, Accuracy: 9957/10000 (100%)
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.000022
#
# Test set: Average loss: 0.0281, Accuracy: 9959/10000 (100%)
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.000004
#
# Test set: Average loss: 0.0285, Accuracy: 9961/10000 (100%)
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0290, Accuracy: 9962/10000 (100%)
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0294, Accuracy: 9961/10000 (100%)
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.000004
#
# Test set: Average loss: 0.0298, Accuracy: 9961/10000 (100%)
#
# Train Epoch: 93 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0302, Accuracy: 9961/10000 (100%)
#
# Train Epoch: 94 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0306, Accuracy: 9960/10000 (100%)
#
# Train Epoch: 95 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0310, Accuracy: 9960/10000 (100%)
#
# Train Epoch: 96 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0313, Accuracy: 9960/10000 (100%)
#
# Train Epoch: 97 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0316, Accuracy: 9959/10000 (100%)
#
# Train Epoch: 98 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0320, Accuracy: 9959/10000 (100%)
#
# Train Epoch: 99 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0324, Accuracy: 9959/10000 (100%)
#
# Train Epoch: 100 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0327, Accuracy: 9959/10000 (100%)
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 423.536163
#
# Test set: Average loss: 0.0969, Accuracy: 9728/10000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.085729
#
# Test set: Average loss: 0.0506, Accuracy: 9847/10000 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.044905
#
# Test set: Average loss: 0.0405, Accuracy: 9868/10000 (99%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.030443
#
# Test set: Average loss: 0.0324, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.039563
#
# Test set: Average loss: 0.0291, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.010231
#
# Test set: Average loss: 0.0259, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.007580
#
# Test set: Average loss: 0.0256, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.006543
#
# Test set: Average loss: 0.0265, Accuracy: 9921/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.010284
#
# Test set: Average loss: 0.0249, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.006189
#
# Test set: Average loss: 0.0252, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.004330
#
# Test set: Average loss: 0.0262, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.002183
#
# Test set: Average loss: 0.0309, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.006447
#
# Test set: Average loss: 0.0272, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.001639
#
# Test set: Average loss: 0.0285, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.003427
#
# Test set: Average loss: 0.0304, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.001865
#
# Test set: Average loss: 0.0328, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.001172
#
# Test set: Average loss: 0.0340, Accuracy: 9924/10000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.000612
#
# Test set: Average loss: 0.0334, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.000501
#
# Test set: Average loss: 0.0303, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.002427
#
# Test set: Average loss: 0.0373, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.012640
#
# Test set: Average loss: 0.0323, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.000910
#
# Test set: Average loss: 0.0338, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.000103
#
# Test set: Average loss: 0.0344, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.000127
#
# Test set: Average loss: 0.0354, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.000136
#
# Test set: Average loss: 0.0365, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.000026
#
# Test set: Average loss: 0.0371, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.000180
#
# Test set: Average loss: 0.0378, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.000012
#
# Test set: Average loss: 0.0383, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.000041
#
# Test set: Average loss: 0.0393, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.000012
#
# Test set: Average loss: 0.0406, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.000083
#
# Test set: Average loss: 0.0407, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.000036
#
# Test set: Average loss: 0.0417, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.000011
#
# Test set: Average loss: 0.0425, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.000010
#
# Test set: Average loss: 0.0426, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.000017
#
# Test set: Average loss: 0.0433, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.000016
#
# Test set: Average loss: 0.0441, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.000016
#
# Test set: Average loss: 0.0451, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.000011
#
# Test set: Average loss: 0.0454, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.000010
#
# Test set: Average loss: 0.0463, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.000003
#
# Test set: Average loss: 0.0466, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0480, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.000004
#
# Test set: Average loss: 0.0489, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0495, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.000003
#
# Test set: Average loss: 0.0495, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.000003
#
# Test set: Average loss: 0.0504, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.000004
#
# Test set: Average loss: 0.0510, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.000003
#
# Test set: Average loss: 0.0517, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0523, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.000002
#
# Test set: Average loss: 0.0528, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0532, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0541, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0550, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0556, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0565, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0569, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0576, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0585, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0590, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0603, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0608, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0613, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0619, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0624, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.000001
#
# Test set: Average loss: 0.0634, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0640, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0647, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0654, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0658, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0665, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0674, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0677, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0688, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0693, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0701, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0703, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0708, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0716, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0723, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0730, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0735, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0741, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0746, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0751, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0756, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0763, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0772, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0777, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0776, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0783, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0787, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0788, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0795, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 93 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0798, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 94 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0804, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 95 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0808, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 96 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0807, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 97 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0812, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 98 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0819, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 99 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0819, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 100 [0/60000 (0%)]	Loss: 0.000000
#
# Test set: Average loss: 0.0825, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 244.423599
#
# Test set: Average loss: 0.0991, Accuracy: 9701/10000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.126655
#
# Test set: Average loss: 0.0579, Accuracy: 9820/10000 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.072705
#
# Test set: Average loss: 0.0445, Accuracy: 9857/10000 (99%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.051466
#
# Test set: Average loss: 0.0387, Accuracy: 9875/10000 (99%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.027628
#
# Test set: Average loss: 0.0328, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.033256
#
# Test set: Average loss: 0.0310, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.021817
#
# Test set: Average loss: 0.0284, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.056367
#
# Test set: Average loss: 0.0268, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.019785
#
# Test set: Average loss: 0.0266, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.002485
#
# Test set: Average loss: 0.0247, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.005945
#
# Test set: Average loss: 0.0234, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.012587
#
# Test set: Average loss: 0.0236, Accuracy: 9928/10000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.005335
#
# Test set: Average loss: 0.0225, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.011284
#
# Test set: Average loss: 0.0242, Accuracy: 9933/10000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.010501
#
# Test set: Average loss: 0.0244, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.009824
#
# Test set: Average loss: 0.0227, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.000343
#
# Test set: Average loss: 0.0242, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.015737
#
# Test set: Average loss: 0.0252, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.002460
#
# Test set: Average loss: 0.0243, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.005085
#
# Test set: Average loss: 0.0253, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.006970
#
# Test set: Average loss: 0.0240, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.045788
#
# Test set: Average loss: 0.0261, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.004295
#
# Test set: Average loss: 0.0243, Accuracy: 9940/10000 (99%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.003036
#
# Test set: Average loss: 0.0267, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.014546
#
# Test set: Average loss: 0.0271, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.001204
#
# Test set: Average loss: 0.0238, Accuracy: 9937/10000 (99%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.003576
#
# Test set: Average loss: 0.0267, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.001966
#
# Test set: Average loss: 0.0303, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.000222
#
# Test set: Average loss: 0.0233, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.002335
#
# Test set: Average loss: 0.0291, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.001102
#
# Test set: Average loss: 0.0300, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.002862
#
# Test set: Average loss: 0.0271, Accuracy: 9938/10000 (99%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.000826
#
# Test set: Average loss: 0.0360, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.037638
#
# Test set: Average loss: 0.0264, Accuracy: 9947/10000 (99%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.000460
#
# Test set: Average loss: 0.0269, Accuracy: 9946/10000 (99%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.000529
#
# Test set: Average loss: 0.0272, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.029653
#
# Test set: Average loss: 0.0346, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.037861
#
# Test set: Average loss: 0.0229, Accuracy: 9947/10000 (99%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.022285
#
# Test set: Average loss: 0.0285, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.000473
#
# Test set: Average loss: 0.0259, Accuracy: 9940/10000 (99%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.003301
#
# Test set: Average loss: 0.0267, Accuracy: 9939/10000 (99%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.003918
#
# Test set: Average loss: 0.0209, Accuracy: 9950/10000 (100%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.000097
#
# Test set: Average loss: 0.0195, Accuracy: 9958/10000 (100%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.000892
#
# Test set: Average loss: 0.0311, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.016122
#
# Test set: Average loss: 0.0299, Accuracy: 9930/10000 (99%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.000230
#
# Test set: Average loss: 0.0303, Accuracy: 9929/10000 (99%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.000297
#
# Test set: Average loss: 0.0381, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.000573
#
# Test set: Average loss: 0.0277, Accuracy: 9944/10000 (99%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.004903
#
# Test set: Average loss: 0.0240, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.001603
#
# Test set: Average loss: 0.0290, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 0.002877
#
# Test set: Average loss: 0.0273, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.012764
#
# Test set: Average loss: 0.0230, Accuracy: 9944/10000 (99%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.004680
#
# Test set: Average loss: 0.0211, Accuracy: 9954/10000 (100%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.000207
#
# Test set: Average loss: 0.0280, Accuracy: 9939/10000 (99%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.003677
#
# Test set: Average loss: 0.0225, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.023734
#
# Test set: Average loss: 0.0228, Accuracy: 9943/10000 (99%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.000306
#
# Test set: Average loss: 0.0243, Accuracy: 9944/10000 (99%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.001682
#
# Test set: Average loss: 0.0265, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 0.009098
#
# Test set: Average loss: 0.0256, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.000454
#
# Test set: Average loss: 0.0344, Accuracy: 9923/10000 (99%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.024448
#
# Test set: Average loss: 0.0222, Accuracy: 9937/10000 (99%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.000497
#
# Test set: Average loss: 0.0223, Accuracy: 9953/10000 (100%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.006025
#
# Test set: Average loss: 0.0202, Accuracy: 9942/10000 (99%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.003781
#
# Test set: Average loss: 0.0286, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.000126
#
# Test set: Average loss: 0.0280, Accuracy: 9932/10000 (99%)
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.000012
#
# Test set: Average loss: 0.0275, Accuracy: 9941/10000 (99%)
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.000118
#
# Test set: Average loss: 0.0229, Accuracy: 9946/10000 (99%)
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.007789
#
# Test set: Average loss: 0.0205, Accuracy: 9953/10000 (100%)
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.000003
#
# Test set: Average loss: 0.0303, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.019811
#
# Test set: Average loss: 0.0291, Accuracy: 9931/10000 (99%)
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.003395
#
# Test set: Average loss: 0.0301, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.006391
#
# Test set: Average loss: 0.0265, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.000123
#
# Test set: Average loss: 0.0242, Accuracy: 9934/10000 (99%)
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.036575
#
# Test set: Average loss: 0.0217, Accuracy: 9951/10000 (100%)
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.006343
#
# Test set: Average loss: 0.0225, Accuracy: 9937/10000 (99%)
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.004472
#
# Test set: Average loss: 0.0230, Accuracy: 9947/10000 (99%)
#
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.000292
#
# Test set: Average loss: 0.0217, Accuracy: 9953/10000 (100%)
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.000750
#
# Test set: Average loss: 0.0186, Accuracy: 9952/10000 (100%)
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.000453
#
# Test set: Average loss: 0.0247, Accuracy: 9953/10000 (100%)
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.000189
#
# Test set: Average loss: 0.0220, Accuracy: 9956/10000 (100%)
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 0.000058
#
# Test set: Average loss: 0.0263, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.005745
#
# Test set: Average loss: 0.0209, Accuracy: 9946/10000 (99%)
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.000039
#
# Test set: Average loss: 0.0213, Accuracy: 9948/10000 (99%)
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.000032
#
# Test set: Average loss: 0.0292, Accuracy: 9943/10000 (99%)
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 0.000152
#
# Test set: Average loss: 0.0278, Accuracy: 9935/10000 (99%)
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.004983
#
# Test set: Average loss: 0.0303, Accuracy: 9936/10000 (99%)
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.000764
#
# Test set: Average loss: 0.0266, Accuracy: 9942/10000 (99%)
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.001760
#
# Test set: Average loss: 0.0226, Accuracy: 9952/10000 (100%)
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.000719
#
# Test set: Average loss: 0.0232, Accuracy: 9942/10000 (99%)
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.000841
#
# Test set: Average loss: 0.0194, Accuracy: 9945/10000 (99%)
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.000029
#
# Test set: Average loss: 0.0225, Accuracy: 9952/10000 (100%)
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.000022
